# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Data ANALYSIS

# %%
df=pd.read_csv('housing.csv')

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB
# (20640, 10)

# %%
pd.unique(df['ocean_proximity'])
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
numericdata=df.select_dtypes(include=[np.number])
colleration_df=numericdata.corr()['median_house_value']
colleration_df
# Out:
# longitude            -0.045967
# latitude             -0.144160
# housing_median_age    0.105623
# total_rooms           0.134153
# total_bedrooms        0.049686
# population           -0.024650
# households            0.065843
# median_income         0.688075
# median_house_value    1.000000
# Name: median_house_value, dtype: float64

# %%
df=df[['housing_median_age','total_rooms','total_bedrooms','median_income','ocean_proximity','median_house_value']]

# %%
df.sample(100)
# Out:
#        housing_median_age  total_rooms  total_bedrooms  median_income  \
# 11909                32.0       2837.0           617.0         2.3798
# 9300                 33.0       9531.0          1487.0         5.6512
# 16681                15.0       5818.0           924.0         4.4033
# 20410                26.0       3135.0           480.0         6.1949
# 5518                 44.0       1097.0           186.0         6.2350
# ...                   ...          ...             ...            ...
# 9546                 14.0       1979.0           432.0         2.6923
# 12591                31.0       1595.0           217.0         6.6112
# 5062                 37.0       1971.0           513.0         1.4625
# 16771                30.0        837.0           213.0         4.8750
# 14731                27.0       1950.0           317.0         4.0656
#
#       ocean_proximity  median_house_value
# 11909          INLAND            118800.0
# ...

# %% [markdown]
# # Univariate analsys

# %%
sns.distplot(x=df['housing_median_age'])
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_15492\2824608914.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['housing_median_age'])
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %%
sns.distplot(x=df['total_rooms'])
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_15492\2283245552.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['total_rooms'])
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %%
sns.distplot(x=df['total_bedrooms'])
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_15492\445598095.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['total_bedrooms'])
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %%
sns.distplot(x=df['median_income'])
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_15492\1259460001.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['median_income'])
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %%
sns.distplot(x=df['housing_median_age'])
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_15492\2824608914.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['housing_median_age'])
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %%
sns.boxplot(df['housing_median_age'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['total_bedrooms'])
# Out:
# <Axes: >

# %% [markdown]
# # mutivariate analysys

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a scatter plot with hue based on 'housing_median_age'
plt.figure(figsize=(10, 6))
sns.scatterplot(x='median_house_value', y='median_income', hue='housing_median_age', data=df)

# Add labels and title
plt.xlabel('Median House Value')
plt.ylabel('Median Income')
plt.title('Scatter Plot: Median House Value vs Median Income with Housing Median Age as Hue')

# Display the plot
plt.show()

# %% [markdown]
# # pandas profiling for EDA

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# C:\Users\lenovo\anaconda3\Lib\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'could not convert string to float: 'NEAR BAY'')
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # DATA CLEANING

# %%
df.sample()
# Out:
#        housing_median_age  total_rooms  total_bedrooms  median_income  \
# 18343                47.0       2600.0           490.0         5.0203
#
#       ocean_proximity  median_house_value
# 18343        NEAR BAY            476300.0

# %%
df['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
df
# Out:
#        housing_median_age  total_rooms  total_bedrooms  median_income  \
# 0                    41.0        880.0           129.0         8.3252
# 1                    21.0       7099.0          1106.0         8.3014
# 2                    52.0       1467.0           190.0         7.2574
# 3                    52.0       1274.0           235.0         5.6431
# 4                    52.0       1627.0           280.0         3.8462
# ...                   ...          ...             ...            ...
# 20635                25.0       1665.0           374.0         1.5603
# 20636                18.0        697.0           150.0         2.5568
# 20637                17.0       2254.0           485.0         1.7000
# 20638                18.0       1860.0           409.0         1.8672
# 20639                16.0       2785.0           616.0         2.3886
#
#       ocean_proximity  median_house_value
# 0            NEAR BAY            452600.0
# ...

# %%
df['ocean_proximity'] = df['ocean_proximity'].replace('<1H OCEAN', 'ONE HOUR')

# %%
df['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', 'ONE HOUR', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
sns.barplot(x='ocean_proximity', y='median_house_value', data=df)
# Out:
# <Axes: xlabel='ocean_proximity', ylabel='median_house_value'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   housing_median_age  20640 non-null  float64
#  1   total_rooms         20640 non-null  float64
#  2   total_bedrooms      20433 non-null  float64
#  3   median_income       20640 non-null  float64
#  4   ocean_proximity     20640 non-null  object
#  5   median_house_value  20640 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 967.6+ KB

# %%
df['total_bedrooms'].fillna(df['total_bedrooms'].mean(), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   housing_median_age  20640 non-null  float64
#  1   total_rooms         20640 non-null  float64
#  2   total_bedrooms      20640 non-null  float64
#  3   median_income       20640 non-null  float64
#  4   ocean_proximity     20640 non-null  object
#  5   median_house_value  20640 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 967.6+ KB

# %%
from sklearn.compose import ColumnTransformer 
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import FunctionTransformer
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.impute import KNNImputer
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV,cross_val_score
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,BaggingRegressor,ExtraTreesRegressor,GradientBoostingRegressor
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder,LabelEncoder,StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression,ridge_regression,SGDRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# #### train test split

# %%
from sklearn.model_selection import train_test_split,cross_val_score
x=df.iloc[:,0:5]
y=df.iloc[:,-1]

X_train, X_test, y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape,y_test.shape
# Out:
# ((16512, 5), (4128, 5), (16512,), (4128,))

# %% [markdown]
# # PREPROCESSING

# %%
num_col=['housing_median_age','total_rooms','total_bedrooms','median_income']
cat_col=['ocean_proximity']

# %%
preprocessor=ColumnTransformer(transformers=[
    ('Ordinal',OneHotEncoder(handle_unknown='ignore',sparse_output=False,drop='first'),cat_col,),
    ('standardScaler',StandardScaler(),num_col,)
    
],remainder='passthrough')

# %%
tf_X_train=preprocessor.fit_transform(X_train)
tf_X_test=preprocessor.transform(X_test)

# %% [markdown]
# #  FINDING BEST MODEL

# %%
models=[RandomForestRegressor(),
        AdaBoostRegressor(),BaggingRegressor(),ExtraTreesRegressor(),GradientBoostingRegressor(),LinearRegression(),SGDRegressor(),SVR(),DecisionTreeRegressor()]

# %%
import time
Name=[]
r2=[]
Time_Taken=[]
for model in models:
    Name.append(type(model).__name__)
    begin=time.time()
    model.fit(tf_X_train,y_train)
    y_pred=model.predict(tf_X_test)
    end=time.time()
    score=r2_score(y_test,y_pred)
    r2.append(score)
    Time_Taken.append(end-begin)

# %%
data={'model':Name,
     'r2_score':r2,
     'time_':Time_Taken
     }
all_model=pd.DataFrame(data)

# %%
all_model
# Out:
#                        model  r2_score      time_
# 0      RandomForestRegressor  0.622012   6.591386
# 1          AdaBoostRegressor  0.317098   0.403499
# 2           BaggingRegressor  0.593506   0.668117
# 3        ExtraTreesRegressor  0.619708   2.777772
# 4  GradientBoostingRegressor  0.644991   1.655975
# 5           LinearRegression  0.593386   0.027870
# 6               SGDRegressor  0.591877   0.024991
# 7                        SVR -0.040304  19.806329
# 8      DecisionTreeRegressor  0.283253   0.099591

# %%
param_grid={
    'n_estimators':[50,100,200],
     'max_depth':[None,10,20,30],
'min_samples_leaf':[1,2,5],
'max_features':[None,'log2','sqrt'],
'max_leaf_nodes':[None,2,5,10,20],
  'n_jobs':[-1]
}

# %%
rfr=RandomForestRegressor(max_depth=20,n_jobs=-1,max_features='log2', n_estimators=200,min_samples_leaf=5)
rfr.fit(tf_X_train,y_train)
y_pred=rfr.predict(tf_X_test)

# %%
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.6515893494875499

# %% [markdown]
# # HYPER PARAMETER TUNING

# %%
param_grid={
    'n_estimators':[50,100,200],
     'max_depth':[None,10,20,30],
'min_samples_leaf':[1,2,5],
'max_features':[None,'log2','sqrt'],
'max_leaf_nodes':[None,2,5,10,20],
  'n_jobs':[-1]
}

# %%
grid_search=GridSearchCV(estimator=rfr,param_grid=param_grid,cv=5,n_jobs=-1,verbose=2)

# %%
grid_search.fit(tf_X_train,y_train)
# Out:
# Fitting 5 folds for each of 540 candidates, totalling 2700 fits

# %%
grid_search.best_params_

# %% [markdown]
# # USING PIPLINES DEployment

# %%
X_train.sample()
# Out:
#        housing_median_age  total_rooms  total_bedrooms  median_income  \
# 10098                25.0       3445.0           801.0         3.4702
#
#       ocean_proximity
# 10098        ONE HOUR

# %%
num_col=['housing_median_age','total_rooms','total_bedrooms','median_income']
cat_col=['ocean_proximity']

# %%
trf1=ColumnTransformer([('standar_scaler_all',StandardScaler(),num_col)],remainder='passthrough')

# %%
trf2=ColumnTransformer([('one_hot_all',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),[4])],remainder='passthrough')

# %%
trf3=RandomForestRegressor(max_depth=20,n_jobs=-1,max_features='log2', n_estimators=200,min_samples_leaf=5)

# %%
pipe = make_pipeline(trf1,trf2,trf3)

# %%
pipe.fit(X_train, y_train)
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer-1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('standar_scaler_all',
#                                                   StandardScaler(),
#                                                   ['housing_median_age',
#                                                    'total_rooms',
# ...

# %%
predictions = pipe.predict(X_test)

# %%
r2=r2_score(y_test,predictions)
r2
# Out:
# 0.6506153868691733

# %%
score= cross_val_score(pipe,X_train,y_train,cv=5,n_jobs=-1)

# %%
score.mean()
# Out:
# 0.6687666970576955

# %%
import pickle
pickle.dump(pipe,open('model.pkl','wb'))

# %%
X_train.sample()
# Out:
#       housing_median_age  total_rooms  total_bedrooms  median_income  \
# 5904                39.0       1769.0           410.0         3.1212
#
#      ocean_proximity
# 5904        ONE HOUR

# %%
X_train['ocean_proximity'].unique()
# Out:
# array(['NEAR OCEAN', 'INLAND', 'ONE HOUR', 'NEAR BAY', 'ISLAND'],
#       dtype=object)
